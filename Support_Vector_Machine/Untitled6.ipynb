# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_set = pd.read_csv('User_data .csv')

# %%
#import os
list(os.walk('/home/nyto/Documents/machine-learning'))[1]
# Out:
# ('/home/nyto/Documents/machine-learning/10 Analyse en Composantes Principales',
#  ['.ipynb_checkpoints'],
#  ['ACP.ipynb', 'Iris.csv', 'Copie de ACP.pdf'])

# %%
data_set.head(15)
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 0   15624510    Male   19            19000          0
# 1   15810944    Male   35            20000          0
# 2   15668575  Female   26            43000          0
# 3   15603246  Female   27            57000          0
# 4   15804002    Male   19            76000          0
# 5   15728773    Male   27            58000          0
# 6   15598044  Female   27            84000          0
# 7   15694829  Female   32           150000          1
# 8   15600575    Male   25            33000          0
# 9   15727311  Female   35            65000          0
# 10  15570769  Female   26            80000          0
# 11  15606274  Female   26            52000          0
# 12  15746139    Male   20            86000          0
# 13  15704987    Male   32            18000          0
# 14  15628972    Male   18            82000          0

# %%
x=data_set.iloc[:,2:4]
y=data_set.iloc[:,4]

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
#split the dataset into training and test set
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
# Featue Scaling
from sklearn.preprocessing import StandardScaler
st_x= StandardScaler()
x_train=st_x.fit_transform(x_train)
x_test=st_x.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.58164944, -0.88670699],
#        [-0.60673761,  1.46173768],
#        [-0.01254409, -0.5677824 ],
#        [-0.60673761,  1.89663484],
#        [ 1.37390747, -1.40858358],
#        [ 1.47293972,  0.99784738],
#        [ 0.08648817, -0.79972756],
#        [-0.01254409, -0.24885782],
#        [-0.21060859, -0.5677824 ],
#        [-0.21060859, -0.19087153],
#        [-0.30964085, -1.29261101],
#        [-0.30964085, -0.5677824 ],
#        [ 0.38358493,  0.09905991],
#        [ 0.8787462 , -0.59677555],
#        [ 2.06713324, -1.17663843],
#        [ 1.07681071, -0.13288524],
#        [ 0.68068169,  1.78066227],
#        [-0.70576986,  0.56295021],
#        [ 0.77971394,  0.35999821],
#        [ 0.8787462 , -0.53878926],
#        [-1.20093113, -1.58254245],
#        [ 2.1661655 ,  0.93986109],
#        [-0.01254409,  1.22979253],
#        [ 0.18552042,  1.08482681],
#        [ 0.38358493, -0.48080297],
#        [-0.30964085, -0.30684411],
#        [ 0.97777845, -0.8287207 ],
# ...

# %%
x_test
# Out:
# array([[-0.80480212,  0.50496393],
#        [-0.01254409, -0.5677824 ],
#        [-0.30964085,  0.1570462 ],
#        [-0.80480212,  0.27301877],
#        [-0.30964085, -0.5677824 ],
#        [-1.10189888, -1.43757673],
#        [-0.70576986, -1.58254245],
#        [-0.21060859,  2.15757314],
#        [-1.99318916, -0.04590581],
#        [ 0.8787462 , -0.77073441],
#        [-0.80480212, -0.59677555],
#        [-1.00286662, -0.42281668],
#        [-0.11157634, -0.42281668],
#        [ 0.08648817,  0.21503249],
#        [-1.79512465,  0.47597078],
#        [-0.60673761,  1.37475825],
#        [-0.11157634,  0.21503249],
#        [-1.89415691,  0.44697764],
#        [ 1.67100423,  1.75166912],
#        [-0.30964085, -1.37959044],
#        [-0.30964085, -0.65476184],
#        [ 0.8787462 ,  2.15757314],
#        [ 0.28455268, -0.53878926],
#        [ 0.8787462 ,  1.02684052],
#        [-1.49802789, -1.20563157],
#        [ 1.07681071,  2.07059371],
#        [-1.00286662,  0.50496393],
# ...

# %%
from sklearn.svm  import  SVC

classificateur = SVC(kernel= 'linear' , random_state= 0 )  
classificateur.fit (x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred=classifier.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 y_pred=classifier.predict(x_test)
#
# NameError: name 'classifier' is not defined

# %%
print(y_pred)

# %%
from matplotlib.colors import ListedColormap

# Créer une colormap pour les points de données
colors = ListedColormap(['red', 'green'])

# Créer la grille de points
x_set, y_set = x_train, y_train
x1, x2 = np.meshgrid(np.arange(start=x_set[:, 0].min() - 1, stop=x_set[:, 0].max() + 1, step=0.01),
                    np.arange(start=x_set[:, 1].min() - 1, stop=x_set[:, 1].max() + 1, step=0.01))

# Calculer les prédictions du modèle sur la grille
Z = classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape)

# Afficher la zone de décision
plt.contourf(x1, x2, Z, cmap='coolwarm', alpha=0.5)

# Afficher les points de données
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1], c=colors(i), label=j)

plt.title("SVM classifier (Training set)")
plt.xlabel("Age")
plt.ylabel("Estimated salary")
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap

# Créer une colormap pour la zone de décision
cmap_decision = ListedColormap(['#FFA07A', '#90EE90'])

# Créer la grille de points
x_set, y_set = x_test, y_test
x1, x2 = np.meshgrid(np.arange(start=x_set[:,0].min()-1,stop=x_set[:,0].max()+1,step=0.01),
                  np.arange(start=x_set[:,1].min()-1,stop=x_set[:,1].max()+1,step=0.01))
plt.contourf(x1, x2, classifier.predict(np.array([x1.ravel(), x2.ravel()]).T).reshape(x1.shape), cmap=cmap_decision, alpha=0.5)
plt.xlim(x1.min(), x1.max())
plt.ylim(x2.min(), x2.max())

# Créer une colormap pour les points de données
colors = ListedColormap(['red', 'green'])

# Afficher les points de données
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(x_set[y_set == j, 0], x_set[y_set == j, 1], c=colors(i), label=j)

plt.title("SVM classifier (Test set)")
plt.xlabel("Age")
plt.ylabel("Estimated salary")
plt.legend()
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Créez un modèle SVM de classification avec un noyau linéaire (vous pouvez choisir un autre noyau si nécessaire)
svc_classifier = SVC(kernel='linear')

# Entraînez le modèle sur l'ensemble d'entraînement
svc_classifier.fit(x_train, y_train)

# Faites des prédictions sur l'ensemble de test
y_pred = svc_classifier.predict(x_test)

# Évaluez les performances du modèle (par exemple, avec la précision)
accuracy = accuracy_score(y_test, y_pred)
print(f"Précision du modèle : {accuracy * 100:.2f}%")

# %%
print(data_set.info())
print(data_set.describe())
